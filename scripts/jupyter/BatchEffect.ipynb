# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
cancer_data = pd.read_csv('../../data/cancer_data_v4.csv')

# fillna
for fea in cancer_data.columns[7:]: # from smoke
    median = cancer_data.groupby(['Origin', 'Age_group', 'A=male B=female'])[fea].median()
    cancer_data.set_index(['Origin', 'Age_group', 'A=male B=female'], inplace=True)
    cancer_data[fea].fillna(median, inplace=True)
    cancer_data.reset_index(inplace=True)

    # sample and merge
seed =657
cancer_data2 = pd.concat([cancer_data[cancer_data['Origin']=='B'],cancer_data[cancer_data['Origin']=='A'].sample(n=212, random_state=seed),cancer_data[cancer_data['Origin']=='C'].sample(n=212, random_state=seed)],axis=0)
feas = cancer_data2.columns[6:]

# PCA
pca = PCA(n_components=4)
data_pca = pca.fit_transform(cancer_data2[feas])
data_pca = pd.DataFrame(data_pca, columns=[f"PC{i}" for i in [1,2,3,4]], index=cancer_data2.index)

data_pca['Origin']=cancer_data2['Origin']

data_pca
# Out:
#              PC1         PC2         PC3         PC4 Origin
# 1862 -200.684723 -109.197028   50.461203   76.447931      B
# 1863 -199.747764  -63.904885   61.988764  -23.250733      B
# 1864 -199.068799   -0.248877  -22.324759  -50.107005      B
# 1865 -200.863072  -95.433397  -25.519827  -70.529793      B
# 1866  104.142656  117.647782  -89.868036  141.615967      B
# ...          ...         ...         ...         ...    ...
# 7554  601.130898   -9.473933   74.132855    4.343036      C
# 6160  300.378796  -13.637659 -100.975080   -3.199869      C
# 4726 -197.912985   65.113077   55.889092  -29.682515      C
# 6198 -198.379132   35.673195  -71.261762   22.282813      C
# 6936  603.532214  143.966466  -46.716876  -22.001080      C
#
# [636 rows x 5 columns]

# %% [markdown]
# # Befroe

# %% [markdown]
# # seed =0

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])

# %% [markdown]
# ## seed=32

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])

# %% [markdown]
# ## seed=657

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])

# %% [markdown]
# # After

# %% [markdown]
# ## seed=0

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])

# %% [markdown]
# ## seed=32

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])

# %% [markdown]
# ## seed=657

# %%
plt.scatter(data_pca[data_pca['Origin']=='A']['PC1'], data_pca[data_pca['Origin']=='A']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='B']['PC1'], data_pca[data_pca['Origin']=='B']['PC2'], marker='.')
plt.scatter(data_pca[data_pca['Origin']=='C']['PC1'], data_pca[data_pca['Origin']=='C']['PC2'], marker='.')
plt.legend(['A','B','C'])
